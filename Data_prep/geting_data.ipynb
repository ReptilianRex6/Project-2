# %%
 
import pandas as pd 
from pybaseball import batting_stats

# %%
data = pd.DataFrame(batting_stats(2014,2019, qual=50))
#show columns info
data
# Out:
#        IDfg  Season                   Name Team  Age    G   AB   PA    H  1B  \
# 2     13611    2018           Mookie Betts  BOS   25  136  520  614  180  96
# 4     10155    2018             Mike Trout  LAA   26  140  471  608  147  80
# 1     11579    2015           Bryce Harper  WSN   22  153  521  654  172  91
# 29    10155    2015             Mike Trout  LAA   23  159  575  682  172  93
# 12    15640    2017            Aaron Judge  NYY   25  155  542  678  154  75
# ...     ...     ...                    ...  ...  ...  ...  ...  ...  ...  ..
# 1698   5557    2014  Jarrod Saltalamacchia  MIA   29  114  373  435   82  51
# 2140    393    2015        Victor Martinez  DET   36  120  440  485  108  77
# 2657  11376    2014         Michael Choice  TEX   24   86  253  280   46  30
# 3068   3448    2019            Jeff Mathis  TEX   36   88  228  244   36  25
# 2843   9272    2018            Chris Davis  BAL   32  128  470  522   79  51
#
#       ...  maxEV  HardHit  HardHit%  Events  CStr%   CSW%  xBA  xSLG  xwOBA  \
# 2     ...  110.6      217     0.500     434  0.220  0.270  NaN   NaN    NaN
# 4     ...  118.0      162     0.460     352  0.201  0.261  NaN   NaN    NaN
# 1     ...  116.0      188     0.477     394  0.118  0.226  NaN   NaN    NaN
# 29    ...  117.7      205     0.486     422  0.207  0.282  NaN   NaN    NaN
# 12    ...  121.1      186     0.550     338  0.157  0.290  NaN   NaN    NaN
# ...   ...    ...      ...       ...     ...    ...    ...  ...   ...    ...
# 1698  ...    NaN        0       NaN       0  0.144  0.306  NaN   NaN    NaN
# 2140  ...  108.9      131     0.332     395  0.163  0.223  NaN   NaN    NaN
# 2657  ...    NaN        0       NaN       0  0.226  0.318  NaN   NaN    NaN
# 3068  ...  105.5       37     0.261     142  0.155  0.322  NaN   NaN    NaN
# 2843  ...  111.8      113     0.401     282  0.174  0.316  NaN   NaN    NaN
#
#       L-WAR
# 2      10.2
# 4       9.5
# 1       9.3
# 29      9.3
# 12      8.7
# ...     ...
# 1698   -2.0
# 2140   -2.0
# 2657   -2.0
# 3068   -2.0
# 2843   -2.5
#
# [3310 rows x 320 columns]

# %%
#create view with only relevant columns for analysis IDfg,Season,Name,Age,PA,H,HR,R,RBI,SB,BB,SO,AVG,OBP,SLG,OPS,wOBA,WAR,BABIP,LD%,GB%,Contact%,SwStr%,Barrel%,EV,maxEV
data_relevant_columns = data[['IDfg','Season','Name','Age','PA','H','HR','R','RBI','SB','BB','SO','AVG','OBP','SLG','OPS','wOBA','WAR','BABIP','LD%','GB%','Contact%','SwStr%','Barrel%','EV','maxEV']]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3310 entries, 2 to 2843
# Columns: 320 entries, IDfg to L-WAR
# dtypes: float64(263), int64(53), object(4)
# memory usage: 8.1+ MB

# %%
# Save data to csv
data.to_csv('../resources/full_batting_data.csv', index=False)
