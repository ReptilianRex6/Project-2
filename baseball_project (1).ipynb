# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor

# import numpy as np
# import random
# from sklearn.linear_model import LinearRegression
# from sklearn.preprocessing import StandardScaler
# from sklearn.neighbors import KNeighborsRegressor
# from sklearn.ensemble import ExtraTreesRegressor, AdaBoostRegressor, GradientBoostingRegressor
# from sklearn.svm import SVR

# %%
def test_model(model, data):
    
    X_train, X_test, y_train, y_test = data
    reg = model.fit(X_train, y_train)
    
    train_score = reg.score(X_train, y_train)
    test_score = reg.score(X_test, y_test)
    
    # print(f'Model: {type(reg).__name__}')
    
    # print(f'Train score: {train_score}')
    # print(f'Test Score: {test_score}\n')    
    
    return {'train':train_score, 'test':test_score}

# %%
data = pd.read_csv('resources/cleaned_extended_data3.csv')
data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 data = pd.read_csv('resources/clean_extended_data.csv')
#       2 data.head()
#
# File c:\Users\abeli\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\abeli\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File c:\Users\abeli\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\abeli\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File c:\Users\abeli\anaconda3\Lib\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'resources/clean_extended_data.csv'

# %%
relevant_cols=['Age','PA','H','HR','R','RBI','SB','BB','SO','AVG','OBP','SLG','OPS','wOBA','WAR','next_year_hits']

# %%
df = data.copy(deep=True)

relevant = df.loc[:,relevant_cols]
relevant = relevant.dropna()

relevant.head()
# Out:
#    Age   PA    H  HR    R  RBI  SB   BB   SO    AVG    OBP    SLG    OPS  \
# 1   25  614  180  32  129   80  30   81   91  0.346  0.438  0.640  1.078
# 2   26  608  147  39  101   79  24  122  124  0.312  0.460  0.628  1.088
# 3   22  654  172  42  118   99   6  124  131  0.330  0.460  0.649  1.109
# 4   23  682  172  41  104   90  11   92  158  0.299  0.402  0.590  0.991
# 5   25  678  154  52  128  114   9  127  208  0.284  0.422  0.627  1.049
#
#     wOBA   WAR  next_year_hits
# 1  0.449  10.4           176.0
# 2  0.447   9.5           137.0
# 3  0.461   9.3           123.0
# 4  0.415   9.3           173.0
# 5  0.430   8.7           115.0

# %%
y = relevant.pop('next_year_hits')
X = relevant

X.head()
# Out:
#    Age   PA    H  HR    R  RBI  SB   BB   SO    AVG    OBP    SLG    OPS  \
# 1   25  614  180  32  129   80  30   81   91  0.346  0.438  0.640  1.078
# 2   26  608  147  39  101   79  24  122  124  0.312  0.460  0.628  1.088
# 3   22  654  172  42  118   99   6  124  131  0.330  0.460  0.649  1.109
# 4   23  682  172  41  104   90  11   92  158  0.299  0.402  0.590  0.991
# 5   25  678  154  52  128  114   9  127  208  0.284  0.422  0.627  1.049
#
#     wOBA   WAR
# 1  0.449  10.4
# 2  0.447   9.5
# 3  0.461   9.3
# 4  0.415   9.3
# 5  0.430   8.7

# %%
X_len = len(X)
X_len
# Out:
# 3224

# %%
def run(model, X, y, model_name):
    
    results = []
    max_r2 = -999.0
    max_index = -999

    idx = 0

    for trees in range(40, 200, 10):
        for depth in range(2, 10, 2):
            
            print(f'\ntrees: {trees}, max-depth: {depth}')
        
            X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
        
            forest_data = [X_train, X_test, y_train, y_test] 
        
            scores = test_model(model(n_estimators=trees, max_depth=depth), forest_data)
        
            results.append((trees, depth, scores['train'], scores['test'], len(X)))
        
            if scores['test']>max_r2:
                max_r2 = scores['test']
                max_index=idx
                print(f'New max score: {max_r2}')
                
            idx += 1
            
    best = results[max_index]
    print(f'\n\nbest {model_name}\ntrain score: {best[2]}\ntest score: {best[3]}\nnum rows: {best[4]}\ntrees: {best[0]}\nmax-depth: {best[1]}\n\n')
    
    return results

# %%
results_rf = run(RandomForestRegressor, X, y, 'RANDOM FOREST')
results_gb = run(GradientBoostingRegressor, X, y, 'GRADIENT BOOSTING')
# Out:
# trees: 40, max-depth: 2
# New max score: 0.2257139486471641
#
# trees: 40, max-depth: 4
# New max score: 0.27423866816631803
#
# trees: 40, max-depth: 6
# New max score: 0.2820741154343863
#
# trees: 40, max-depth: 8
# New max score: 0.2853651860009343
#
# trees: 50, max-depth: 2
#
# trees: 50, max-depth: 4
#
# trees: 50, max-depth: 6
#
# trees: 50, max-depth: 8
#
# trees: 60, max-depth: 2
#
# trees: 60, max-depth: 4
#
# trees: 60, max-depth: 6
#
# trees: 60, max-depth: 8
#
# trees: 70, max-depth: 2
#
# trees: 70, max-depth: 4
#
# trees: 70, max-depth: 6
#
# trees: 70, max-depth: 8
#
# trees: 80, max-depth: 2
#
# trees: 80, max-depth: 4
#
# trees: 80, max-depth: 6
#
# trees: 80, max-depth: 8
#
# trees: 90, max-depth: 2
#
# trees: 90, max-depth: 4
#
# trees: 90, max-depth: 6
#
# trees: 90, max-depth: 8
#
# trees: 100, max-depth: 2
#
# trees: 100, max-depth: 4
#
# trees: 100, max-depth: 6
#
# trees: 100, max-depth: 8
#
# trees: 110, max-depth: 2
#
# trees: 110, max-depth: 4
#
# trees: 110, max-depth: 6
#
# trees: 110, max-depth: 8
#
# trees: 120, max-depth: 2
#
# trees: 120, max-depth: 4
#
# trees: 120, max-depth: 6
#
# trees: 120, max-depth: 8
#
# trees: 130, max-depth: 2
#
# trees: 130, max-depth: 4
#
# trees: 130, max-depth: 6
#
# trees: 130, max-depth: 8
#
# trees: 140, max-depth: 2
#
# trees: 140, max-depth: 4
#
# trees: 140, max-depth: 6
#
# trees: 140, max-depth: 8
#
# trees: 150, max-depth: 2
#
# trees: 150, max-depth: 4
#
# trees: 150, max-depth: 6
#
# trees: 150, max-depth: 8
#
# trees: 160, max-depth: 2
#
# trees: 160, max-depth: 4
#
# trees: 160, max-depth: 6
#
# trees: 160, max-depth: 8
#
# trees: 170, max-depth: 2
#
# trees: 170, max-depth: 4
#
# trees: 170, max-depth: 6
#
# trees: 170, max-depth: 8
#
# trees: 180, max-depth: 2
#
# trees: 180, max-depth: 4
#
# trees: 180, max-depth: 6
#
# trees: 180, max-depth: 8
#
# trees: 190, max-depth: 2
#
# trees: 190, max-depth: 4
#
# trees: 190, max-depth: 6
#
# trees: 190, max-depth: 8
#
#
# best RANDOM FOREST
# train score: 0.6119410260054875
# test score: 0.2853651860009343
# num rows: 3224
# trees: 40
# max-depth: 8
#
#
#
# trees: 40, max-depth: 2
# New max score: 0.2721060548091271
#
# trees: 40, max-depth: 4
# New max score: 0.2777153178505226
#
# trees: 40, max-depth: 6
#
# trees: 40, max-depth: 8
#
# trees: 50, max-depth: 2
#
# trees: 50, max-depth: 4
# New max score: 0.2817160282487856
#
# trees: 50, max-depth: 6
#
# trees: 50, max-depth: 8
#
# trees: 60, max-depth: 2
#
# trees: 60, max-depth: 4
# New max score: 0.2844929814321725
#
# trees: 60, max-depth: 6
#
# trees: 60, max-depth: 8
#
# trees: 70, max-depth: 2
#
# trees: 70, max-depth: 4
# New max score: 0.28835437503776495
#
# trees: 70, max-depth: 6
#
# trees: 70, max-depth: 8
#
# trees: 80, max-depth: 2
#
# trees: 80, max-depth: 4
# New max score: 0.289470912632261
#
# trees: 80, max-depth: 6
#
# trees: 80, max-depth: 8
#
# trees: 90, max-depth: 2
#
# trees: 90, max-depth: 4
# New max score: 0.2926745214544568
#
# trees: 90, max-depth: 6
#
# trees: 90, max-depth: 8
#
# trees: 100, max-depth: 2
#
# trees: 100, max-depth: 4
# New max score: 0.2945956156771057
#
# trees: 100, max-depth: 6
#
# trees: 100, max-depth: 8
#
# trees: 110, max-depth: 2
#
# trees: 110, max-depth: 4
#
# trees: 110, max-depth: 6
#
# trees: 110, max-depth: 8
#
# trees: 120, max-depth: 2
#
# trees: 120, max-depth: 4
#
# trees: 120, max-depth: 6
#
# trees: 120, max-depth: 8
#
# trees: 130, max-depth: 2
#
# trees: 130, max-depth: 4
#
# trees: 130, max-depth: 6
#
# trees: 130, max-depth: 8
#
# trees: 140, max-depth: 2
#
# trees: 140, max-depth: 4
#
# trees: 140, max-depth: 6
#
# trees: 140, max-depth: 8
#
# trees: 150, max-depth: 2
#
# trees: 150, max-depth: 4
#
# trees: 150, max-depth: 6
#
# trees: 150, max-depth: 8
#
# trees: 160, max-depth: 2
#
# trees: 160, max-depth: 4
#
# trees: 160, max-depth: 6
#
# trees: 160, max-depth: 8
#
# trees: 170, max-depth: 2
#
# trees: 170, max-depth: 4
#
# trees: 170, max-depth: 6
#
# trees: 170, max-depth: 8
#
# trees: 180, max-depth: 2
#
# trees: 180, max-depth: 4
#
# trees: 180, max-depth: 6
#
# trees: 180, max-depth: 8
#
# trees: 190, max-depth: 2
#
# trees: 190, max-depth: 4
#
# trees: 190, max-depth: 6
#
# trees: 190, max-depth: 8
#
#
# best GRADIENT BOOSTING
# train score: 0.6029766786766719
# test score: 0.2945956156771057
# num rows: 3224
# trees: 100
# max-depth: 4

# %%
# # standard regressors
# test_model(LinearRegression(), data)

# test_model(KNeighborsRegressor(), data)
# test_model(RandomForestRegressor(), data)
# test_model(ExtraTreesRegressor(), data)
# test_model(AdaBoostRegressor(), data)
# test_model(SVR(C=1.0, epsilon=0.2), data)
# test_model(GradientBoostingRegressor(), data)
