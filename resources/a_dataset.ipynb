# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pybaseball as pyball

# %%
a_dataset = pd.read_csv('/Users/karliebaxter/Project-2/resources/dataset.csv')
a_dataset
# Out:
#        IDfg             Name  Age   PA    H  HR    R  RBI  SB   BB  ...  \
# 0     13611     Mookie Betts   25  614  180  32  129   80  30   81  ...
# 1     10155       Mike Trout   26  608  147  39  101   79  24  122  ...
# 2     11579     Bryce Harper   22  654  172  42  118   99   6  124  ...
# 3     10155       Mike Trout   23  682  172  41  104   90  11   92  ...
# 4     15640      Aaron Judge   25  678  154  52  128  114   9  127  ...
# ...     ...              ...  ...  ...  ...  ..  ...  ...  ..  ...  ...
# 4275    393  Victor Martinez   36  485  108  11   39   64   0   31  ...
# 4276   5677       A.J. Ellis   33  347   54   3   21   25   0   53  ...
# 4277  11376   Michael Choice   24  280   46   9   20   36   1   21  ...
# 4278   3448      Jeff Mathis   36  244   36   2   17   12   1   15  ...
# 4279   9272      Chris Davis   32  522   79  16   40   49   2   41  ...
#
#        wOBA   WAR  BABIP    LD%    GB%  Contact%  SwStr%  Barrel%    EV  maxEV
# ...

# %%
a_dataset.value_counts('Name')
# Out:
# Name
# Rougned Odor        8
# Justin Upton        8
# Carlos Santana      8
# Tommy La Stella     8
# Cesar Hernandez     8
#                    ..
# R.A. Dickey         1
# Hoy Park            1
# Humberto Arteaga    1
# Phillip Evans       1
# Zelous Wheeler      1
# Name: count, Length: 1262, dtype: int64
